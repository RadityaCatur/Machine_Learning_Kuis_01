# %% [markdown]
# ## _Medical Insurance Costs_
#
# Pada kasus ini, terdapat data tentang informasi kesehatan dan biaya yang harus dikeluarkan oleh asuransi kesehatan.
# Infomasi terkait dengan data _medical insurance cost_ adalah sebagai berikut,
#
# 1. Age: Usia penerima manfaat
# 2. Sex: Gender penerima manfaat (_male_, _female_)
# 3. Bmi : Body Mass Index
# 4. Children: Jumlah anak/tanggungan yang dicover oleh pihak asuransi
# 5. Smoker: Status perokok (_yes_, _no_)
# 6. Region: Wilayah tempat tinggal penerima manfaat
# 7. Charges: Biaya yang dikeluarkan oleh asuransi

# %%
# Selayang pandang data Medical Insurance Costs
import pandas as pd

df = pd.read_csv('data/insurance.csv')

display(df.head())

display(df.corr())

# %% [markdown]
# ### Tantangan
#
# Buatlah model regresi untuk memprediksi biaya yang harus dikeluarkan oleh pihak asuransi berdasarkan data.
# Validasi performa model regresi Anda dengan nilai ***R-squared ($R^2$)***
#
# #### _Tasks_
#
# 1. Pastikan semua variabel kategorial diolah dengan baik. (Gunakan fitur mapping pada pandas)
# 2. Cek kondisi multicollinearity untuk semua variabel independen. Jika ada, antar variabel apakah itu?
# 3. Pastikan model menggunakan variabel yang tidak memiliki nilai multicollinearity yang tinggi
# 4. (Hints) Anda dapat menggunakan nilai ***Variance Inflation Factor (VIF)*** untuk mengetahui tingkat multicollinearity pada sebuah variabel independent.
# 5. Evaluasi model yang Anda buat dengan nilai $R^2$
# 6. Simpulkan, variabel independen apa saja yang dapat digunakan untuk menghasilkan model regresi yang baik pada kasus _medical insurance costs_?

# %% [markdown]
# #### (Hints) Interpretasi Nilai VIF
#
# - 1 - variabel indenpenden tidak memiliki korelasi dengan variabel independen yang lain
# - 1 < VIF < 5 - variabel independen sedikit memiliki korelasi dengan variabel independen yang lain
# - VIF > 5 - variabel independen memiliki korelasi yang kuat dengan variabel independen lainnya
# - VIF > 10 - variabel independen miliki korelasi yang sangat kuat dengan variabel independen dan perlu diperhatikan lebih lanjut
#
# #### (Hints) Implementasi Perhitungan VIF
#
# VIF dapat dihitung secara langsung dengan menggunakan library dari `statsmodels`

# %% [markdown]
# #### (Hints) Scatterplot Korelasi Antar Variabel
#
# ![var_cor](assets/var_corr.png)

# %% [markdown]
# ## Mulai Mengerjakan!
#
# Memastikan semua variabel kategorial diolah dengan baik. (Menggunakan fitur mapping pada pandas)
#
# Variabel kategorial pada data yaitu ada variabel 'sex', 'smoker', dan 'region'

# %%
from sklearn.preprocessing import OneHotEncoder

oe_sex = [
    [ 'male' ],
    [ 'female' ]
]

oe_sex = OneHotEncoder().fit_transform(oe_sex)

oe_sex = oe_sex.toarray()

# %%
oe_smoker = [
    [ 'yes' ],
    [ 'no' ]
]

oe_smoker = OneHotEncoder().fit_transform(oe_smoker)

oe_smoker = oe_smoker.toarray()

# %%
oe_region = [
    [ 'southwest' ],
    [ 'northwest' ]
]

oe_region = OneHotEncoder().fit_transform(oe_region)

oe_region = oe_region.toarray()

# %%
# import library untuk visualisasi
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
# operasi visualisasi
sns.pairplot(df, x_vars=['age', oe_sex,'bmi', 'children', oe_smoker, oe_region], 
             y_vars='charges', size=4, aspect=1, kind='scatter')
plt.show()
# Out:
# c:\Users\Radit\anaconda3\lib\site-packages\seaborn\axisgrid.py:2076: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# c:\Users\Radit\anaconda3\lib\site-packages\matplotlib\text.py:1215: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if s != self._text:
# c:\Users\Radit\anaconda3\lib\site-packages\seaborn\axisgrid.py:1416: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if x_var == y_var:
# c:\Users\Radit\anaconda3\lib\site-packages\seaborn\axisgrid.py:1394: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if x_var != y_var:
# c:\Users\Radit\anaconda3\lib\site-packages\seaborn\axisgrid.py:1557: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if x_var == y_var:
# c:\Users\Radit\anaconda3\lib\site-packages\numpy\core\_asarray.py:102: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return array(a, dtype, copy=False, order=order)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8144/2399948125.py in <module>
#       1 # operasi visualisasi
# ----> 2 sns.pairplot(df, x_vars=['age', oe_sex,'bmi', 'children', oe_smoker, oe_region],
#       3              y_vars='charges', size=4, aspect=1, kind='scatter')
#       4 plt.show()
#
# c:\Users\Radit\anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# c:\Users\Radit\anaconda3\lib\site-packages\seaborn\axisgrid.py in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, height, aspect, corner, dropna, plot_kws, diag_kws, grid_kws, size)
#    2138     if kind == "scatter":
#    2139         from .relational import scatterplot  # Avoid circular import
# -> 2140         plotter(scatterplot, **plot_kws)
#    2141     elif kind == "reg":
#    2142         from .regression import regplot  # Avoid circular import
#
# c:\Users\Radit\anaconda3\lib\site-packages\seaborn\axisgrid.py in map_offdiag(self, func, **kwargs)
#    1394                     if x_var != y_var:
#    1395                         indices.append((i, j))
# -> 1396             self._map_bivariate(func, indices, **kwargs)
#    1397         return self
#    1398
#
# c:\Users\Radit\anaconda3\lib\site-packages\seaborn\axisgrid.py in _map_bivariate(self, func, indices, **kwargs)
#    1537             if ax is None:  # i.e. we are in corner mode
#    1538                 continue
# -> 1539             self._plot_bivariate(x_var, y_var, ax, func, **kws)
#    1540         self._add_axis_labels()
#    1541
#
# c:\Users\Radit\anaconda3\lib\site-packages\seaborn\axisgrid.py in _plot_bivariate(self, x_var, y_var, ax, func, **kwargs)
#    1563             axes_vars.append(self._hue_var)
#    1564
# -> 1565         data = self.data[axes_vars]
#    1566         if self._dropna:
#    1567             data = data.dropna()
#
# c:\Users\Radit\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3462             if is_iterator(key):
#    3463                 key = list(key)
# -> 3464             indexer = self.loc._get_listlike_indexer(key, axis=1)[1]
#    3465
#    3466         # take() does not accept boolean indexers
#
# c:\Users\Radit\anaconda3\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis)
#    1307
#    1308         if ax._index_as_unique:
# -> 1309             indexer = ax.get_indexer_for(keyarr)
#    1310             keyarr = ax.reindex(keyarr)[0]
#    1311         else:
#
# c:\Users\Radit\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_indexer_for(self, target, **kwargs)
#    5273         """
#    5274         if self._index_as_unique:
# -> 5275             return self.get_indexer(target, **kwargs)
#    5276         indexer, _ = self.get_indexer_non_unique(target)
#    5277         return indexer
#
# c:\Users\Radit\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_indexer(self, target, method, limit, tolerance)
#    3484             )
#    3485
# -> 3486         return self._get_indexer(target, method, limit, tolerance)
#    3487
#    3488     def _get_indexer(
#
# c:\Users\Radit\anaconda3\lib\site-packages\pandas\core\indexes\base.py in _get_indexer(self, target, method, limit, tolerance)
#    3510             indexer = self._get_nearest_indexer(target, limit, tolerance)
#    3511         else:
# -> 3512             indexer = self._engine.get_indexer(target._get_engine_target())
#    3513
#    3514         return ensure_platform_int(indexer)
#
# c:\Users\Radit\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_indexer()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.lookup()
#
# TypeError: unhashable type: 'numpy.ndarray'

# %%
sns.heatmap(df.corr(), cmap="YlGnBu", annot = True)
plt.show()

# %% [markdown]
# Dari bentuk visualisasi di atas terlihat bahwa Age memiliki korelasi yang paling kuat terhadap Charges

# %% [markdown]
# ### Regresi Linier

# %%
# Buat variabel bebas X dan Y, sebagai contoh ambil dari hasil analisis korelasi dari kegaitan sebelumnya
X = df['age']
y = df['charges']

# %%
# Buat pemisahan data uji dan data latih dengan proporsi 7:3
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size = 0.7, 
                                                    test_size = 0.3, random_state = 100)

# %%
# hasil training dtaset
X_train
y_train
# Out:
# 966     23967.38305
# 522      9866.30485
# 155      6948.70080
# 671      3943.59540
# 1173     6457.84340
#            ...
# 802      2103.08000
# 53      37742.57570
# 350     11830.60720
# 79       6571.02435
# 792      2731.91220
# Name: charges, Length: 936, dtype: float64

# %%
# training model
import statsmodels.api as sm

X_train_sm = sm.add_constant(X_train)

# %%
# fitting garis regresi
lr = sm.OLS(y_train, X_train_sm).fit()
lr.params
# Out:
# const    2707.051837
# age       267.740141
# dtype: float64

# %%
# analisis statistika dari garis regresi
lr.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                charges   R-squared:                       0.097
# Model:                            OLS   Adj. R-squared:                  0.096
# Method:                 Least Squares   F-statistic:                     99.76
# Date:                Fri, 30 Sep 2022   Prob (F-statistic):           2.18e-22
# Time:                        08:18:06   Log-Likelihood:                -10082.
# No. Observations:                 936   AIC:                         2.017e+04
# Df Residuals:                     934   BIC:                         2.018e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       2707.0518   1113.327      2.431      0.015     522.139    4891.965
# age          267.7401     26.806      9.988      0.000     215.133     320.348
# ==============================================================================
# Omnibus:                      284.664   Durbin-Watson:                   1.925
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              613.549
# Skew:                           1.743   Prob(JB):                    5.88e-134
# Kurtosis:                       4.891   Cond. No.                         123.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
# visualisasi garis regresi
plt.scatter(X_train, y_train)
plt.plot(X_train, 265.2483 + 66.3015*X_train, 'r')
plt.show()
